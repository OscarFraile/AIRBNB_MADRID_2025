# %% [markdown]
# # PLANTILLA EDA

# %% [markdown]
# ## 1. IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Automcompletar rápido
# %config IPCompleter.greedy=True

#Formato sin notación científica
pd.options.display.float_format = '{:15.2f}'.format

# %% [markdown]
# ## 2. IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/Python Data Mastery/EstructuraDirectorio/03_MACHINE_LEARNING/08_CASOS/007_AIRBNB'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_cat = 'cat_resultado_calidad.pickle'
nombre_num = 'num_resultado_calidad.pickle'

# %% [markdown]
# Cargar los datos.

# %%
cat = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_cat)
num = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_num)

# %% [markdown]
# ## 3. EDA CATEGÓRICAS

# %% [markdown]
# ### 3.1. Análisis estadístico

# %%
cat.columns.to_list()
# Out:
# ['name',
#  'host_response_time',
#  'host_is_superhost',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'property_type',
#  'room_type',
#  'amenities',
#  'has_availability',
#  'license',
#  'instant_bookable',
#  'neighbourhood_group',
#  'host_since',
#  'first_review',
#  'last_review',
#  'bedrooms_disc',
#  'accommodates_disc',
#  'beds_disc',
#  'number_of_reviews_disc']

# %%
incluir_cat = cat.columns.to_list()

#Eliminamos las columnas que estén en la siguiente lista
for i in sorted([0, 6, 8, 13, 14, 15], reverse=True):
    del incluir_cat[i]

# %%
def frecuencias_cat(cat):
    # Asegúrate de que todas las columnas son de tipo 'str' para evitar problemas de comparación
    cat = cat[incluir_cat]
    
    resultado = cat.apply(lambda x: x.value_counts(normalize = True))\
                .T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return resultado

# %%
cat[incluir_cat].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18139 entries, 21853 to 1308864880309321118
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   host_response_time      18139 non-null  object
#  1   host_is_superhost       18139 non-null  object
#  2   host_verifications      18139 non-null  object
#  3   host_has_profile_pic    18139 non-null  object
#  4   host_identity_verified  18139 non-null  object
#  5   room_type               18139 non-null  object
#  6   has_availability        18139 non-null  object
#  7   license                 18139 non-null  object
#  8   instant_bookable        18139 non-null  object
#  9   neighbourhood_group     18139 non-null  object
#  10  bedrooms_disc           18139 non-null  object
#  11  accommodates_disc       18139 non-null  object
#  12  beds_disc               18139 non-null  object
#  13  number_of_reviews_disc  18139 non-null  object
# dtypes: object(14)
# memory usage: 2.1+ MB

# %%
pd.set_option('display.max_rows', None)

frecuencias_cat(cat[incluir_cat])
#Aparecerá una lista de todas las variables con su frecuencia asociada
# Out:
#                   Variable                             Valor      Frecuencia
# 54       accommodates_disc                              4-16            0.16
# 53       accommodates_disc                                 4            0.24
# 52       accommodates_disc                               0-3            0.59
# 51           bedrooms_disc                   04_Cuatro o mas            0.03
# 50           bedrooms_disc                           03_Tres            0.07
# 47           bedrooms_disc                        00_Estudio            0.15
# 49           bedrooms_disc                            02_Dos            0.20
# 48           bedrooms_disc                            01_Una            0.55
# 57               beds_disc                              3-19            0.09
# 56               beds_disc                                 3            0.41
# 55               beds_disc                                 1            0.50
# 20        has_availability                                no            0.06
# 21        has_availability                               yes            0.94
# 13    host_has_profile_pic                                 f            0.03
# 14    host_has_profile_pic                                 t            0.97
# 15  host_identity_verified                                 f            0.11
# 16  host_identity_verified                                 t            0.89
# 6        host_is_superhost                                 t            0.26
# 5        host_is_superhost                                 f            0.74
# 0       host_response_time                a few days or more            0.04
# 2       host_response_time                      within a day            0.06
# 3       host_response_time                within a few hours            0.11
# 1       host_response_time                       no response            0.19
# 4       host_response_time                    within an hour            0.59
# 7       host_verifications                            ['No']            0.00
# 10      host_verifications                         ['email']            0.00
# 11      host_verifications           ['phone', 'work_email']            0.02
# 8       host_verifications  ['email', 'phone', 'work_email']            0.10
# 12      host_verifications                         ['phone']            0.10
# 9       host_verifications                ['email', 'phone']            0.77
# 25        instant_bookable                                 t            0.40
# 24        instant_bookable                                 f            0.60
# 23                 license                               yes            0.10
# 22                 license                                no            0.90
# 44     neighbourhood_group                         Vicálvaro            0.00
# 45     neighbourhood_group                 Villa de Vallecas            0.01
# 27     neighbourhood_group                           Barajas            0.01
# 37     neighbourhood_group                         Moratalaz            0.01
# 46     neighbourhood_group                        Villaverde            0.01
# 33     neighbourhood_group                        Fuencarral            0.01
# 34     neighbourhood_group                         Hortaleza            0.02
# 41     neighbourhood_group                          San Blas            0.02
# 43     neighbourhood_group                             Usera            0.02
# 36     neighbourhood_group                           Moncloa            0.03
# 35     neighbourhood_group                            Latina            0.03
# 38     neighbourhood_group                Puente de Vallecas            0.03
# 30     neighbourhood_group                         Chamartín            0.03
# 32     neighbourhood_group                     Ciudad Lineal            0.04
# 39     neighbourhood_group                            Retiro            0.04
# 28     neighbourhood_group                       Carabanchel            0.04
# 26     neighbourhood_group                        Arganzuela            0.05
# 42     neighbourhood_group                            Tetuán            0.06
# 31     neighbourhood_group                          Chamberí            0.06
# 40     neighbourhood_group                         Salamanca            0.07
# 29     neighbourhood_group                            Centro            0.41
# 60  number_of_reviews_disc                           71-1136            0.20
# 59  number_of_reviews_disc                              5-71            0.29
# 58  number_of_reviews_disc                               1-4            0.51
# 19               room_type                       Shared room            0.01
# 18               room_type                      Private room            0.32
# 17               room_type                   Entire home/apt            0.67

# %% [markdown]
# ### 3.2. Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
  
    # Filtrar solo columnas numéricas seleccionadas en incluir_num
    cat = cat[incluir_cat]

    # Verificar si hay columnas numéricas
    if cat.shape[1] == 0:
        print("No hay columnas categóricas para graficar.")
        return    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat)

# %% [markdown]
# ## 4. EDA NUMÉRICAS

# %% [markdown]
# ### 4.1. Análisis estadístico

# %%
incluir_num = num.columns.to_list()

#Eliminamos las columnas que estén en la siguiente lista
for i in sorted([0], reverse=True):
    del incluir_num[i]

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
num[incluir_num].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18139 entries, 21853 to 1308864880309321118
# Data columns (total 37 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_id                                       18139 non-null  int64
#  1   host_response_rate                            18139 non-null  float64
#  2   host_acceptance_rate                          18139 non-null  float64
#  3   host_listings_count                           18139 non-null  float64
#  4   host_total_listings_count                     18139 non-null  float64
#  5   latitude                                      18139 non-null  float64
#  6   longitude                                     18139 non-null  float64
#  7   accommodates                                  18139 non-null  int64
#  8   bathrooms                                     18139 non-null  float64
#  9   bedrooms                                      18139 non-null  float64
#  10  beds                                          18139 non-null  float64
#  11  price                                         18139 non-null  int64
#  12  minimum_nights                                18139 non-null  int64
#  13  maximum_nights                                18139 non-null  int64
#  14  availability_30                               18139 non-null  int64
#  15  availability_60                               18139 non-null  int64
#  16  availability_90                               18139 non-null  int64
#  17  availability_365                              18139 non-null  int64
#  18  number_of_reviews                             18139 non-null  int64
#  19  number_of_reviews_ltm                         18139 non-null  int64
#  20  number_of_reviews_l30d                        18139 non-null  int64
#  21  review_scores_rating                          18139 non-null  float64
#  22  review_scores_accuracy                        18139 non-null  float64
#  23  review_scores_cleanliness                     18139 non-null  float64
#  24  review_scores_checkin                         18139 non-null  float64
#  25  review_scores_communication                   18139 non-null  float64
#  26  review_scores_location                        18139 non-null  float64
#  27  review_scores_value                           18139 non-null  float64
#  28  calculated_host_listings_count                18139 non-null  int64
#  29  calculated_host_listings_count_entire_homes   18139 non-null  int64
#  30  calculated_host_listings_count_private_rooms  18139 non-null  int64
#  31  calculated_host_listings_count_shared_rooms   18139 non-null  int64
#  32  reviews_per_month                             18139 non-null  float64
#  33  precio_m2                                     18139 non-null  int64
#  34  m2                                            18139 non-null  int64
#  35  pdi_sol                                       18139 non-null  float64
#  36  pisos_rentables                               18139 non-null  int64
# dtypes: float64(18), int64(19)
# memory usage: 5.3 MB

# %%
pd.set_option('display.max_rows', None)

estadisticos_cont(num[incluir_num])
#Aparecerá una lista de todas las variables con su frecuencia asociada
# Out:
#                                                        count            mean  \
# host_id                                             18139.00    247862242.73
# host_response_rate                                  18139.00           74.59
# host_acceptance_rate                                18139.00           84.68
# host_listings_count                                 18139.00           49.89
# host_total_listings_count                           18139.00           61.09
# latitude                                            18139.00           40.42
# longitude                                           18139.00           -3.69
# accommodates                                        18139.00            3.16
# bathrooms                                           18139.00            1.28
# bedrooms                                            18139.00            1.30
# beds                                                18139.00            1.85
# price                                               18139.00          130.45
# minimum_nights                                      18139.00            7.98
# maximum_nights                                      18139.00          523.70
# availability_30                                     18139.00            9.83
# availability_60                                     18139.00           24.76
# availability_90                                     18139.00           41.24
# availability_365                                    18139.00          163.47
# number_of_reviews                                   18139.00           47.69
# number_of_reviews_ltm                               18139.00           14.63
# number_of_reviews_l30d                              18139.00            1.05
# review_scores_rating                                18139.00            3.72
# review_scores_accuracy                              18139.00            3.76
# review_scores_cleanliness                           18139.00            3.75
# review_scores_checkin                               18139.00            3.80
# review_scores_communication                         18139.00            3.81
# review_scores_location                              18139.00            3.80
# review_scores_value                                 18139.00            3.65
# calculated_host_listings_count                      18139.00           34.76
# calculated_host_listings_count_entire_homes         18139.00           31.07
# calculated_host_listings_count_private_rooms        18139.00            3.54
# calculated_host_listings_count_shared_rooms         18139.00            0.15
# reviews_per_month                                   18139.00            1.50
# precio_m2                                           18139.00         5317.01
# m2                                                  18139.00           57.68
# pdi_sol                                             18139.00            2.78
# pisos_rentables                                     18139.00            0.70
#
#                                                       median             std  \
# host_id                                         208980277.00    203475000.33
# host_response_rate                                    100.00           40.75
# host_acceptance_rate                                   97.00           24.51
# host_listings_count                                     3.00          134.00
# host_total_listings_count                               5.00          189.92
# latitude                                               40.42            0.02
# longitude                                              -3.70            0.03
# accommodates                                            3.00            1.89
# bathrooms                                               1.00            0.61
# bedrooms                                                1.00            0.98
# beds                                                    1.00            1.25
# price                                                  98.00          398.77
# minimum_nights                                          2.00           27.34
# maximum_nights                                        365.00          421.01
# availability_30                                         8.00            9.76
# availability_60                                        24.00           21.08
# availability_90                                        44.00           32.98
# availability_365                                      158.00          134.39
# number_of_reviews                                      11.00           87.78
# number_of_reviews_ltm                                   4.00           21.90
# number_of_reviews_l30d                                  0.00            1.81
# review_scores_rating                                    4.68            1.91
# review_scores_accuracy                                  4.75            1.93
# review_scores_cleanliness                               4.71            1.92
# review_scores_checkin                                   4.80            1.94
# review_scores_communication                             4.83            1.95
# review_scores_location                                  4.79            1.93
# review_scores_value                                     4.58            1.88
# calculated_host_listings_count                          3.00           79.85
# calculated_host_listings_count_entire_homes             1.00           78.56
# calculated_host_listings_count_private_rooms            0.00           16.52
# calculated_host_listings_count_shared_rooms             0.00            1.95
# reviews_per_month                                       0.77            1.88
# precio_m2                                            6170.00         1520.06
# m2                                                     50.00           18.44
# pdi_sol                                                 2.03            2.45
# pisos_rentables                                         1.00            0.46
#
#                                                          min             25%  \
# host_id                                              7952.00     48380095.00
# host_response_rate                                      0.00           65.00
# host_acceptance_rate                                    0.00           82.00
# host_listings_count                                     1.00            1.00
# host_total_listings_count                               1.00            2.00
# latitude                                               40.33           40.41
# longitude                                              -3.83           -3.71
# accommodates                                            1.00            2.00
# bathrooms                                               0.00            1.00
# bedrooms                                                0.00            1.00
# beds                                                    0.00            1.00
# price                                                  20.00           65.00
# minimum_nights                                          1.00            1.00
# maximum_nights                                          1.00          300.00
# availability_30                                         0.00            0.00
# availability_60                                         0.00            0.00
# availability_90                                         0.00            0.00
# availability_365                                        0.00           19.00
# number_of_reviews                                       0.00            1.00
# number_of_reviews_ltm                                   0.00            0.00
# number_of_reviews_l30d                                  0.00            0.00
# review_scores_rating                                    0.00            4.00
# review_scores_accuracy                                  0.00            4.11
# review_scores_cleanliness                               0.00            4.00
# review_scores_checkin                                   0.00            4.25
# review_scores_communication                             0.00            4.21
# review_scores_location                                  0.00            4.19
# review_scores_value                                     0.00            4.00
# calculated_host_listings_count                          1.00            1.00
# calculated_host_listings_count_entire_homes             0.00            0.00
# calculated_host_listings_count_private_rooms            0.00            0.00
# calculated_host_listings_count_shared_rooms             0.00            0.00
# reviews_per_month                                       0.00            0.06
# precio_m2                                            2070.00         4536.00
# m2                                                     40.00           50.00
# pdi_sol                                                 0.00            0.84
# pisos_rentables                                         0.00            0.00
#
#                                                          50%             75%  \
# host_id                                         208980277.00    440993833.00
# host_response_rate                                    100.00          100.00
# host_acceptance_rate                                   97.00          100.00
# host_listings_count                                     3.00           23.00
# host_total_listings_count                               5.00           30.00
# latitude                                               40.42           40.43
# longitude                                              -3.70           -3.68
# accommodates                                            3.00            4.00
# bathrooms                                               1.00            1.50
# bedrooms                                                1.00            2.00
# beds                                                    1.00            2.00
# price                                                  98.00          140.00
# minimum_nights                                          2.00            4.00
# maximum_nights                                        365.00         1125.00
# availability_30                                         8.00           17.00
# availability_60                                        24.00           43.00
# availability_90                                        44.00           72.00
# availability_365                                      158.00          299.00
# number_of_reviews                                      11.00           54.00
# number_of_reviews_ltm                                   4.00           22.00
# number_of_reviews_l30d                                  0.00            2.00
# review_scores_rating                                    4.68            4.89
# review_scores_accuracy                                  4.75            4.92
# review_scores_cleanliness                               4.71            4.91
# review_scores_checkin                                   4.80            4.95
# review_scores_communication                             4.83            4.97
# review_scores_location                                  4.79            4.95
# review_scores_value                                     4.58            4.80
# calculated_host_listings_count                          3.00           17.00
# calculated_host_listings_count_entire_homes             1.00           11.00
# calculated_host_listings_count_private_rooms            0.00            1.00
# calculated_host_listings_count_shared_rooms             0.00            0.00
# reviews_per_month                                       0.77            2.33
# precio_m2                                            6170.00         6170.00
# m2                                                     50.00           70.00
# pdi_sol                                                 2.03            4.11
# pisos_rentables                                         1.00            1.00
#
#                                                          max
# host_id                                         666295558.00
# host_response_rate                                    100.00
# host_acceptance_rate                                  100.00
# host_listings_count                                  3251.00
# host_total_listings_count                            7970.00
# latitude                                               40.53
# longitude                                              -3.55
# accommodates                                           16.00
# bathrooms                                              15.00
# bedrooms                                               12.00
# beds                                                   19.00
# price                                               21347.00
# minimum_nights                                       1125.00
# maximum_nights                                       1125.00
# availability_30                                        30.00
# availability_60                                        60.00
# availability_90                                        90.00
# availability_365                                      365.00
# number_of_reviews                                    1040.00
# number_of_reviews_ltm                                 302.00
# number_of_reviews_l30d                                 24.00
# review_scores_rating                                    5.00
# review_scores_accuracy                                  5.00
# review_scores_cleanliness                               5.00
# review_scores_checkin                                   5.00
# review_scores_communication                             5.00
# review_scores_location                                  5.00
# review_scores_value                                     5.00
# calculated_host_listings_count                        343.00
# calculated_host_listings_count_entire_homes           343.00
# calculated_host_listings_count_private_rooms          175.00
# calculated_host_listings_count_shared_rooms            38.00
# reviews_per_month                                      25.76
# precio_m2                                            7846.00
# m2                                                    150.00
# pdi_sol                                                14.53
# pisos_rentables                                         1.00

# %% [markdown]
# ### 4.2. Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    # Filtrar solo columnas numéricas seleccionadas en incluir_num
    num = num[incluir_num]

    # Verificar si hay columnas numéricas
    if num.shape[1] == 0:
        print("No hay columnas numéricas para graficar.")
        return
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_continuas(num)

# %% [markdown]
# ## 5. GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guardamos los avances en cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.

# %%
#Definir los nombres de los archivos
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_eda.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_eda.pickle'

# %%
#Guardar los archivos
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
